# %%
import pandas as pd
import selenium 
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import re

# %%
Path = 'C:\Program Files (x86)\chromedriver.exe'

driver = webdriver.Chrome(Path)

# %%
driver.get("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.price_range.from%3D7000&sort=popularity&p%5B%5D=facets.price_range.to%3D10000&otracker=clp_creative_card_2_54.creativeCard.CREATIVE_CARD_mobile-phones-store_ML48SGJEH4G7&fm=neo%2Fmerchandising&iid=M_eefaaa89-c617-4421-8ee1-cde0cf477631_54.ML48SGJEH4G7&ppt=clp&ppn=mobile-phones-store&ssid=lxwlsunvi80000001636354549475")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
review = []

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
len(review)
# Out:
# 24

# %%
nrev = []

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])
#Numreview
# Out:
# ['10,886 Reviews',
#  '10,886 Reviews',
#  '3,655 Reviews',
#  '3,655 Reviews',
#  '5,611 Reviews',
#  '5,611 Reviews',
#  '4,260 Reviews',
#  '4,260 Reviews',
#  '288 Reviews',
#  '5,209 Reviews',
#  '5,209 Reviews',
#  '288 Reviews',
#  '4,059 Reviews',
#  '4,059 Reviews',
#  '147 Reviews',
#  '488 Reviews',
#  '488 Reviews',
#  '3,528 Reviews',
#  '3,528 Reviews',
#  '319 Reviews',
#  '534 Reviews',
#  '1,073 Reviews',
#  '1,073 Reviews',
#  '29,391 Reviews']

# %%
Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1])
#Numrating
# Out:
# ['2,29,616 Ratings &',
#  '2,29,616 Ratings &',
#  '66,119 Ratings &',
#  '66,119 Ratings &',
#  '1,12,813 Ratings &',
#  '1,12,813 Ratings &',
#  '1,01,059 Ratings &',
#  '1,01,059 Ratings &',
#  '13,546 Ratings &',
#  '1,55,410 Ratings &',
#  '1,55,410 Ratings &',
#  '13,546 Ratings &',
#  '84,249 Ratings &',
#  '84,249 Ratings &',
#  '3,704 Ratings &',
#  '17,409 Ratings &',
#  '17,409 Ratings &',
#  '51,772 Ratings &',
#  '51,772 Ratings &',
#  '9,794 Ratings &',
#  '13,608 Ratings &',
#  '14,190 Ratings &',
#  '14,190 Ratings &',
#  '4,99,808 Ratings &']

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
len(url)
# Out:
# 24

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])
#Numreview
# Out:
# ['10,886 Reviews',
#  '10,886 Reviews',
#  '3,655 Reviews',
#  '3,655 Reviews',
#  '5,611 Reviews',
#  '5,611 Reviews',
#  '4,260 Reviews',
#  '4,260 Reviews',
#  '288 Reviews',
#  '5,209 Reviews',
#  '5,209 Reviews',
#  '288 Reviews',
#  '4,059 Reviews',
#  '4,059 Reviews',
#  '147 Reviews',
#  '488 Reviews',
#  '488 Reviews',
#  '3,528 Reviews',
#  '3,528 Reviews',
#  '319 Reviews',
#  '534 Reviews',
#  '1,073 Reviews',
#  '1,073 Reviews',
#  '29,391 Reviews',
#  '1,073 Reviews',
#  '8,791 Reviews',
#  '8,791 Reviews',
#  '8,791 Reviews',
#  '1,073 Reviews',
#  '29,391 Reviews',
#  '147 Reviews',
#  '8,791 Reviews',
#  '304 Reviews',
#  '304 Reviews',
#  '235 Reviews',
#  '5,433 Reviews',
#  '5,353 Reviews',
#  '5,353 Reviews',
#  '5,353 Reviews',
#  '5,353 Reviews',
#  '3,905 Reviews',
#  '3,905 Reviews',
#  '2,279 Reviews',
#  '2,279 Reviews',
#  '4,940 Reviews',
#  '4,940 Reviews',
#  '4,940 Reviews',
#  '3,905 Reviews']

# %%
Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1])
#Numrating
# Out:
# ['2,29,616 Ratings &',
#  '2,29,616 Ratings &',
#  '66,119 Ratings &',
#  '66,119 Ratings &',
#  '1,12,813 Ratings &',
#  '1,12,813 Ratings &',
#  '1,01,059 Ratings &',
#  '1,01,059 Ratings &',
#  '13,546 Ratings &',
#  '1,55,410 Ratings &',
#  '1,55,410 Ratings &',
#  '13,546 Ratings &',
#  '84,249 Ratings &',
#  '84,249 Ratings &',
#  '3,704 Ratings &',
#  '17,409 Ratings &',
#  '17,409 Ratings &',
#  '51,772 Ratings &',
#  '51,772 Ratings &',
#  '9,794 Ratings &',
#  '13,608 Ratings &',
#  '14,190 Ratings &',
#  '14,190 Ratings &',
#  '4,99,808 Ratings &',
#  '14,190 Ratings &',
#  '1,26,328 Ratings &',
#  '1,26,328 Ratings &',
#  '1,26,328 Ratings &',
#  '14,190 Ratings &',
#  '4,99,808 Ratings &',
#  '3,704 Ratings &',
#  '1,26,328 Ratings &',
#  '4,309 Ratings &',
#  '4,309 Ratings &',
#  '4,769 Ratings &',
#  '60,698 Ratings &',
#  '72,216 Ratings &',
#  '72,216 Ratings &',
#  '72,216 Ratings &',
#  '72,216 Ratings &',
#  '63,188 Ratings &',
#  '63,188 Ratings &',
# ...

# %%
url = []
try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        #time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[3])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
len(url), len(review), len(nrev)
# Out:
# (24, 96, 96)

# %%
driver.get(link[4])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[5])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[6])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[7])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[8])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[9])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link[10])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.price_range.from%3D7000&sort=popularity&p%5B%5D=facets.price_range.to%3D10000&otracker=clp_creative_card_2_54.creativeCard.CREATIVE_CARD_mobile-phones-store_ML48SGJEH4G7&fm=neo%2Fmerchandising&iid=M_eefaaa89-c617-4421-8ee1-cde0cf477631_54.ML48SGJEH4G7&ppt=clp&ppn=mobile-phones-store&ssid=lxwlsunvi80000001636354549475&page=15")
link1 =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link1.append(elem.get_attribute("href"))

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
driver.get(link1[1])

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
len(review), len(nrev)
# Out:
# (288, 288)

# %%
driver.get(link1[2])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link1[3])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link1[4])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
driver.get(link1[5])

# %%
url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review
# Out:
# ['Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Good handy phone with decent performance. Good for the first time smartphone users. battery backup is pro level, network availability is good,not that heavy. i prefer this to c11 as it has CGG protection.',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  'Very nice phone from realme . Loved it Camera is good battery is also good and design is awesome',
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
#  "Really nice phone, delivery is so fast that's excellent, good battery and desplay performance , camera is also good Must buy",
# ...

# %%
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev
# Out:
# [['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '2,29,616 Ratings &', '10,886 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '66,119 Ratings &', '3,655 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,12,813 Ratings &', '5,611 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.4★', '1,01,059 Ratings &', '4,260 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.5★', '1,55,410 Ratings &', '5,209 Reviews'],
#  ['4.6★', '13,546 Ratings &', '288 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.3★', '84,249 Ratings &', '4,059 Reviews'],
#  ['4.5★', '3,704 Ratings &', '147 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.6★', '17,409 Ratings &', '488 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
#  ['4.3★', '51,772 Ratings &', '3,528 Reviews'],
# ...

# %%
len(review),len(nrev)
# Out:
# (384, 384)

# %%
driver.get(link1[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (408, 408)

# %%
driver.get(link1[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link1[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link1[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link1[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (504, 504)

# %%
driver.get("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.price_range.from%3D7000&sort=popularity&p%5B%5D=facets.price_range.to%3D10000&otracker=clp_creative_card_2_54.creativeCard.CREATIVE_CARD_mobile-phones-store_ML48SGJEH4G7&fm=neo%2Fmerchandising&iid=M_eefaaa89-c617-4421-8ee1-cde0cf477631_54.ML48SGJEH4G7&ppt=clp&ppn=mobile-phones-store&ssid=lxwlsunvi80000001636354549475&page=25")
link2 =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link2.append(elem.get_attribute("href"))

# %%
driver.get(link2[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link2[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
Rating = []

for i in range(len(nrev)):
       Rating.append(nrev[i][0])
Rating
# Out:
# ['4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.6★',
#  '4.5★',
#  '4.5★',
#  '4.6★',
#  '4.3★',
#  '4.3★',
#  '4.5★',
#  '4.6★',
#  '4.6★',
#  '4.3★',
#  '4.3★',
#  '4.4★',
#  '4.4★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.5★',
#  '4.3★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.1★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.4★',
#  '4.5★',
#  '4.5★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '4.4★',
#  '4.4★',
#  '4★',
#  '4.4★',
#  '4.4★',
#  '4.2★',
#  '3.8★',
#  '4★',
#  '4★',
#  '4.2★',
#  '4.2★',
#  '5★',
#  '5★',
#  '4.3★',
#  '4.3★',
#  '4.2★',
#  '4★',
#  '4.1★',
#  '4.1★',
#  '4.1★',
#  '4.1★',
#  '4.2★',
#  '4★',
#  '4.1★',
#  '4.2★',
#  '4.2★',
#  '4.2★',
#  '4.2★',
#  '4.2★',
#  '4.3★',
#  '4★',
#  '4.1★',
#  '4.1★',
#  '4.9★',
#  '4.9★',
#  '4.9★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '3.8★',
#  '4.2★',
#  '4.3★',
#  '4.3★',
#  '4.3★',
#  '-',
# ...

# %%
Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])

        Numreview
# Out:
# ['10,886 Reviews',
#  '10,886 Reviews',
#  '3,655 Reviews',
#  '3,655 Reviews',
#  '5,611 Reviews',
#  '5,611 Reviews',
#  '4,260 Reviews',
#  '4,260 Reviews',
#  '288 Reviews',
#  '5,209 Reviews',
#  '5,209 Reviews',
#  '288 Reviews',
#  '4,059 Reviews',
#  '4,059 Reviews',
#  '147 Reviews',
#  '488 Reviews',
#  '488 Reviews',
#  '3,528 Reviews',
#  '3,528 Reviews',
#  '319 Reviews',
#  '534 Reviews',
#  '1,073 Reviews',
#  '1,073 Reviews',
#  '29,391 Reviews',
#  '1,073 Reviews',
#  '8,791 Reviews',
#  '8,791 Reviews',
#  '8,791 Reviews',
#  '1,073 Reviews',
#  '29,391 Reviews',
#  '147 Reviews',
#  '8,791 Reviews',
#  '304 Reviews',
#  '304 Reviews',
#  '235 Reviews',
#  '5,433 Reviews',
#  '5,353 Reviews',
#  '5,353 Reviews',
#  '5,353 Reviews',
#  '5,353 Reviews',
#  '3,905 Reviews',
#  '3,905 Reviews',
#  '2,279 Reviews',
#  '2,279 Reviews',
#  '4,940 Reviews',
#  '4,940 Reviews',
#  '4,940 Reviews',
#  '3,905 Reviews',
#  '3,905 Reviews',
#  '93 Reviews',
#  '235 Reviews',
# ...

# %%
Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1:-1])
Numrating
# Out:
# [['2,29,616 Ratings &'],
#  ['2,29,616 Ratings &'],
#  ['66,119 Ratings &'],
#  ['66,119 Ratings &'],
#  ['1,12,813 Ratings &'],
#  ['1,12,813 Ratings &'],
#  ['1,01,059 Ratings &'],
#  ['1,01,059 Ratings &'],
#  ['13,546 Ratings &'],
#  ['1,55,410 Ratings &'],
#  ['1,55,410 Ratings &'],
#  ['13,546 Ratings &'],
#  ['84,249 Ratings &'],
#  ['84,249 Ratings &'],
#  ['3,704 Ratings &'],
#  ['17,409 Ratings &'],
#  ['17,409 Ratings &'],
#  ['51,772 Ratings &'],
#  ['51,772 Ratings &'],
#  ['9,794 Ratings &'],
#  ['13,608 Ratings &'],
#  ['14,190 Ratings &'],
#  ['14,190 Ratings &'],
#  ['4,99,808 Ratings &'],
#  ['14,190 Ratings &'],
#  ['1,26,328 Ratings &'],
#  ['1,26,328 Ratings &'],
#  ['1,26,328 Ratings &'],
#  ['14,190 Ratings &'],
#  ['4,99,808 Ratings &'],
#  ['3,704 Ratings &'],
#  ['1,26,328 Ratings &'],
#  ['4,309 Ratings &'],
#  ['4,309 Ratings &'],
#  ['4,769 Ratings &'],
#  ['60,698 Ratings &'],
#  ['72,216 Ratings &'],
#  ['72,216 Ratings &'],
#  ['72,216 Ratings &'],
# ...

# %%
data = pd.DataFrame({})
data['Rating'] = Rating
data['Review'] = review
data['Number of Ratings'] = Numrating
data['Number of Reviews'] = Numreview

# %%
data
# Out:
#     Rating                                             Review  \
# 0     4.4★  Good handy phone with decent performance. Good...
# 1     4.4★  Good handy phone with decent performance. Good...
# 2     4.4★  Very nice phone from realme . Loved it Camera ...
# 3     4.4★  Very nice phone from realme . Loved it Camera ...
# 4     4.4★  Really nice phone, delivery is so fast that's ...
# ..     ...                                                ...
# 715   3.9★                                 very nice product.
# 716   4.5★  1.Best in class day today performance.\n2. Bes...
# 717   3.8★  An average android phone with a average displa...
# 718   3.6★                         ITS GOOD. SUPER. EXCELLENT
# 719   4.4★  The first thing i liked on this phone is the d...
#
#          Number of Ratings Number of Reviews
# 0     [2,29,616 Ratings &]    10,886 Reviews
# 1     [2,29,616 Ratings &]    10,886 Reviews
# 2       [66,119 Ratings &]     3,655 Reviews
# ...

# %%
data.to_csv("Data", index = False)

# %%
driver.get("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.price_range.from%3D7000&sort=popularity&p%5B%5D=facets.price_range.to%3D10000&otracker=clp_creative_card_2_54.creativeCard.CREATIVE_CARD_mobile-phones-store_ML48SGJEH4G7&fm=neo%2Fmerchandising&iid=M_eefaaa89-c617-4421-8ee1-cde0cf477631_54.ML48SGJEH4G7&ppt=clp&ppn=mobile-phones-store&ssid=lxwlsunvi80000001636354549475&page=35")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []
review = []
nrev = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(nrev), len(review)
# Out:
# (240, 240)

# %%
df = pd.read_csv("Data")
df
# Out:
#     Rating                                             Review  \
# 0     4.4★  Good handy phone with decent performance. Good...
# 1     4.4★  Good handy phone with decent performance. Good...
# 2     4.4★  Very nice phone from realme . Loved it Camera ...
# 3     4.4★  Very nice phone from realme . Loved it Camera ...
# 4     4.4★  Really nice phone, delivery is so fast that's ...
# ..     ...                                                ...
# 715   3.9★                                 very nice product.
# 716   4.5★  1.Best in class day today performance.\n2. Bes...
# 717   3.8★  An average android phone with a average displa...
# 718   3.6★                         ITS GOOD. SUPER. EXCELLENT
# 719   4.4★  The first thing i liked on this phone is the d...
#
#            Number of Ratings Number of Reviews
# 0     ['2,29,616 Ratings &']    10,886 Reviews
# 1     ['2,29,616 Ratings &']    10,886 Reviews
# 2       ['66,119 Ratings &']     3,655 Reviews
# ...

# %%
df['Rating']
# Out:
# 0      4.4★
# 1      4.4★
# 2      4.4★
# 3      4.4★
# 4      4.4★
#        ...
# 715    3.9★
# 716    4.5★
# 717    3.8★
# 718    3.6★
# 719    4.4★
# Name: Rating, Length: 720, dtype: object

# %%
df['Rating'].nunique()
# Out:
# 19

# %%
df['Rating'].value_counts()
# Out:
# 4.3★    152
# 4.4★    133
# 4.2★     98
# 4.1★     69
# 4★       65
# 3.9★     44
# 3.8★     41
# 3.7★     35
# 4.5★     34
# -        19
# 3.6★      8
# 3.3★      4
# 5★        4
# 3.5★      4
# 4.6★      4
# 4.9★      3
# 3★        1
# 3.4★      1
# 3.2★      1
# Name: Rating, dtype: int64

# %%
driver.get("https://www.flipkart.com/search?sid=ajy&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.find_element_by_xpath("//a[@class = '_2rpwqI']").get_attribute("href")
# Out:
# 'https://www.flipkart.com/aroma-i29-sporty-smartwatch/p/itmb53e2097ff9f9?pid=SMWG6Z9EZFVF373H&lid=LSTSMWG6Z9EZFVF373HF0FETU&marketplace=FLIPKART&store=ajy&srno=b_1_1&otracker=CLP_Filters&fm=organic&iid=en_30zoWNtzYdmu4qP%2B7dlqyWcxinSMRMO5ZmglUhjDet2NuyNBgDE4DjAeJftjjDEUmjDQWSzmHcQFCrlk3du0ow%3D%3D&ppt=None&ppn=None&ssid=yed9ywogxs0000001637142580576'

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(nrev), len(review)
# Out:
# (280, 280)

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (640, 640)

# %%
driver.get("https://www.flipkart.com/search?sid=tyy%2C4mr&otracker=CLP_Filters&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3D100")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(nrev), len(review)
# Out:
# (1040, 1040)

# %%
driver.get("https://www.flipkart.com/search?sid=fcn&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&sort=recency_desc")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (1440, 1440)

# %%
driver.get("https://www.flipkart.com/search?sid=fcn&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&sort=recency_desc&page=15")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(nrev), len(review)
# Out:
# (1800, 1800)

# %%
driver.get("https://www.flipkart.com/search?sid=fcn&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&sort=recency_desc&page=25")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (2000, 2000)

# %%
Rating = []

for i in range(len(nrev)):
       Rating.append(nrev[i][0])
Rating

Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])
Numreview

Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1:-1])
Numrating
# Out:
# [['34,669 Ratings &'],
#  ['1,648 Ratings &'],
#  ['9,582 Ratings &'],
#  ['36 Ratings &'],
#  ['10,504 Ratings &'],
#  ['7,636 Ratings &'],
#  ['27,250 Ratings &'],
#  ['9,433 Ratings &'],
#  ['24 Ratings &'],
#  ['193 Ratings &'],
#  ['66,047 Ratings &'],
#  ['4,893 Ratings &'],
#  ['6,42,617 Ratings &'],
#  ['11 Ratings &'],
#  ['11,72,834 Ratings &'],
#  ['132 Ratings &'],
#  ['13,41,455 Ratings &'],
#  ['341 Ratings &'],
#  ['6,06,120 Ratings &'],
#  ['6,06,120 Ratings &'],
#  ['4,893 Ratings &'],
#  ['4,893 Ratings &'],
#  ['4,893 Ratings &'],
#  ['1,78,612 Ratings &'],
#  ['70 Ratings &'],
#  ['1,463 Ratings &'],
#  ['3,362 Ratings &'],
#  ['20,686 Ratings &'],
#  ['4,55,266 Ratings &'],
#  ['940 Ratings &'],
#  ['38 Ratings &'],
#  ['10 Ratings &'],
#  ['192 Ratings &'],
#  ['486 Ratings &'],
#  ['50,933 Ratings &'],
#  ['9,433 Ratings &'],
#  ['4,147 Ratings &'],
#  ['32 Ratings &'],
#  ['7,636 Ratings &'],
#  ['460 Ratings &'],
#  ['3,465 Ratings &'],
#  ['69 Ratings &'],
# ...

# %%
data = pd.DataFrame({})
data['Rating'] = Rating
data['Review'] = review
data['Number of Ratings'] = Numrating
data['Number of Reviews'] = Numreview

# %%
data.to_csv("Data1", index = False)

# %%
Da
# Out:
#      Rating                                             Review  \
# 0      4.2★  great product 👍 , smooth performance, great ca...
# 1        4★  Nice product from flipkart... I trust this app...
# 2      4.3★  This is the best smart phone in cheap price th...
# 3      3.1★  Oppo N1 Mini(5inch),the smaller sibling to the...
# 4      4.2★  Great mobile very handy and cool look.\n\nPosi...
# ...     ...                                                ...
# 1995   3.5★                                      Velu of monny
# 1996   3.7★                    Build quality is not much good.
# 1997   2.8★                                                  -
# 1998   1.7★                                                  -
# 1999   2.6★                 It is very bad one side low volume
#
#        Number of Ratings Number of Reviews
# 0     [34,669 Ratings &]     2,917 Reviews
# 1      [1,648 Ratings &]       263 Reviews
# 2      [9,582 Ratings &]       640 Reviews
# ...

# %%
driver.get("https://www.flipkart.com/search?sid=6bo%2Cai3&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3D500")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(nrev), len(review)
# Out:
# (2400, 2400)

# %%
driver.get("https://www.flipkart.com/search?sid=6bo%2Cai3&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3D500&page=15")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review),len(nrev)
# Out:
# (2800, 2800)

# %%
driver.get("https://www.flipkart.com/search?sid=tyy%2C4mr&otracker=CLP_Filters&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3D100&page=25")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (3000, 3000)

# %%
Rating = []

for i in range(len(nrev)):
       Rating.append(nrev[i][0])
Rating

Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])
Numreview

Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1:-1])
#Numrating

# %%
data = pd.DataFrame({})
data['Rating'] = Rating
data['Review'] = review
data['Number of Ratings'] = Numrating
data['Number of Reviews'] = Numreview

# %%
data.to_csv("Data2", index = False)

# %%
driver.get("https://www.flipkart.com/search?sid=4rr&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []
review = []
nrev = []
try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(review), len(nrev)
# Out:
# (400, 400)

# %%
driver.get("https://www.flipkart.com/search?sid=4rr&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&page=15")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except:
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
len(nrev), len(review)
# Out:
# (800, 800)

# %%
driver.get("https://www.flipkart.com/search?sid=4rr&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&page=25")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (1000, 1000)

# %%
driver.get("https://www.flipkart.com/computers/desktop-pcs/all-in-one-pcs/pr?sid=6bo%2Cnl4%2Cigk&wid=6.productCard.PMU_V2_4&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (1081, 1081)

# %%
driver.get("https://www.flipkart.com/computers/pr?sid=6bo&otracker=categorytree")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (1481, 1481)

# %%
driver.get("https://www.flipkart.com/computers/pr?sid=6bo&otracker=categorytree&page=15")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (1884, 1881)

# %%
driver.get("https://www.flipkart.com/computers/pr?sid=6bo&otracker=categorytree&page=25")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(nrev), len(review)
# Out:
# (2081, 2084)

# %%
driver.get("https://www.flipkart.com/search?sid=hry&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(nrev), len(review)
# Out:
# (2481, 2484)

# %%
driver.get("https://www.flipkart.com/search?sid=hry&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&page=15")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(nrev), len(review)
# Out:
# (2881, 2884)

# %%
driver.get("https://www.flipkart.com/search?sid=hry&otracker=CLP_Filters&p%5B%5D=facets.rating%255B%255D%3D1%25E2%2598%2585%2B%2526%2Babove&page=25")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (3084, 3081)

# %%
Rating = []

for i in range(len(nrev)):
       Rating.append(nrev[i][0])
Rating

Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])
Numreview

Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1:-1])
#Numrating

# %%
data = pd.DataFrame({})
data['Rating'] = Rating[:3081]
data['Review'] = review[:3081]
data['Number of Ratings'] = Numrating[:3081]
data['Number of Reviews'] = Numreview[:3081]

# %%
data.to_csv("Data3", index = False)

# %%
driver.get("https://www.flipkart.com/computers/network-components/pr?sid=6bo,70k&otracker=categorytree&otracker=nmenu_sub_Electronics_0_Network%20Components")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []
review = []
nrev = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []


try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []


try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []


try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []


try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review) , len(nrev)
# Out:
# (400, 400)

# %%
driver.get("https://www.flipkart.com/computers/network-components/pr?sid=6bo%2C70k&otracker=categorytree&otracker=nmenu_sub_Electronics_0_Network+Components&page=15")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (800, 800)

# %%
driver.get("https://www.flipkart.com/computers/network-components/pr?sid=6bo%2C70k&otracker=categorytree&otracker=nmenu_sub_Electronics_0_Network+Components&page=25")

# %%
link =[]
elems = driver.find_elements_by_xpath("//nav//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[3])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[4])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[5])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[6])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[7])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[8])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[9])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[10])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='_2rpwqI']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='t-ZTKy']")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_xpath("//div[@class='col']")
        time.sleep(2)
        nrev.append(rev.text.split("\n"))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(review), len(nrev)
# Out:
# (1000, 1000)

# %%
len(nrev), len(review), nrev[-1] ,nrev, review
# Out:
# (1000,
#  1000,
#  ['4★', '1,747 Ratings &', '353 Reviews'],
#  [['4.5★', '9,393 Ratings &', '1,462 Reviews'],
#   ['4.4★', '815 Ratings &', '104 Reviews'],
#   ['4.4★', '37,559 Ratings &', '5,174 Reviews'],
#   ['4★', '2,363 Ratings &', '292 Reviews'],
#   ['4.3★', '2,804 Ratings &', '269 Reviews'],
#   ['4.1★', '10 Ratings &', '2 Reviews'],
#   ['4.2★', '5,864 Ratings &', '675 Reviews'],
#   ['4.3★', '720 Ratings &', '74 Reviews'],
#   ['4.4★', '274 Ratings &', '22 Reviews'],
#   ['4.3★', '314 Ratings &', '33 Reviews'],
#   ['4.3★', '8,519 Ratings &', '1,294 Reviews'],
#   ['4.1★', '4,150 Ratings &', '950 Reviews'],
#   ['4.2★', '462 Ratings &', '41 Reviews'],
#   ['3.9★', '584 Ratings &', '68 Reviews'],
#   ['3.9★', '13,191 Ratings &', '1,646 Reviews'],
#   ['4.2★', '158 Ratings &', '15 Reviews'],
#   ['4.2★', '131 Ratings &', '9 Reviews'],
#   ['4.2★', '981 Ratings &', '170 Reviews'],
#   ['3.8★', '1,179 Ratings &', '166 Reviews'],
#   ['4.4★', '635 Ratings &', '120 Reviews'],
# ...

# %%
Rating = []

for i in range(len(nrev)):
       Rating.append(nrev[i][0])
Rating

Numreview = []
for i in range(len(nrev)):
       Numreview.append(nrev[i][-1])
Numreview

Numrating = []
for i in range(len(nrev)):
       Numrating.append(nrev[i][1:-1])
#Numrating

# %%
data = pd.DataFrame({})
data['Rating'] = Rating
data['Review'] = review
data['Number of Ratings'] = Numrating
data['Number of Reviews'] = Numreview

# %%
data.to_csv("Data4", index = False)

# %%
driver.get("https://www.amazon.in/s?i=electronics&bbn=1389401031&rh=n%3A1389401031%2Cp_72%3A1318479031&dc&qid=1637057983&rnid=1318475031&ref=sr_pg_1")

# %%
link =[]
elems = driver.find_elements_by_xpath("//li//a[@href]")
for elem in elems:
    link.append(elem.get_attribute("href"))

# %%
url = []

lk = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
for i in lk:
    url.append(i.get_attribute('href'))

# %%
len(url)
# Out:
# 33

# %%
driver.get(url[0])

# %%
driver.find_element_by_id("acrCustomerReviewText").text
# Out:
# '4,665 ratings'

# %%
driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']").text
# Out:
# '4.6 out of 5'

# %%
driver.find_element_by_xpath("//span[@class='a-size-base review-text']").text
# Out:
# 'nice'

# %%
driver.get(link[0])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_id("acrCustomerReviewText")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url: 
    driver.get(i)
    
    try:
        rat = driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")
        rating.append(rat.text)
        
    except:
        rating.append("-")
        
for i in url:
    driver.get(i)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    try:
        rev = driver.find_element_by_xpath("//span[@class='a-size-base review-text']")
        time.sleep(2)
        nrev.append(rev.text.split(","))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[1])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_id("acrCustomerReviewText")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url: 
    driver.get(i)
    
    try:
        rat = driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")
        rating.append(rat.text)
        
    except:
        rating.append("-")
        
for i in url:
    driver.get(i)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    try:
        rev = driver.find_element_by_xpath("//span[@class='a-size-base review-text']")
        time.sleep(2)
        nrev.append(rev.text.split(","))
    
    except:
        nrev.append('-')

#nrev1

# %%
driver.get(link[2])

url = []

try:
    lk = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for i in lk:
        url.append(i.get_attribute('href'))

except: 
    url.append('-')
    
for i in url:
    driver.get(i)
    
    try:
        rev = driver.find_element_by_id("acrCustomerReviewText")
        #time.sleep(2)
        review.append(rev.text)
    
    except:
        review.append('-')

#review

for i in url: 
    driver.get(i)
    
    try:
        rat = driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")
        rating.append(rat.text)
        
    except:
        rating.append("-")
        
for i in url:
    driver.get(i)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    try:
        rev = driver.find_element_by_xpath("//span[@class='a-size-base review-text']")
        time.sleep(2)
        nrev.append(rev.text.split(","))
    
    except:
        nrev.append('-')

#nrev1

# %%
len(rating), len(nrev), len(review)
# Out:
# (198, 231, 235)

# %%
nrev
# Out:
# [[' Nice product and good quality'],
#  ['best product ever, i gift to someone. his is very happy. easy to install and use. quality was good. also price was good. and hold the phone very tightly, no need to worry its fall down. best for gps or tracking map.'],
#  [' I liked a lot. Would like to share my friends'],
#  ['Update after 1 month of use.',
#   'There is crackling sound in the background that comes during calls games music anything randomly. During calls, once the crackling starts, it continues. It is known issue with the buds, and you need to reset the device to get it back, and then again the crackling starts in 3-10 hours.',
#   '',
#   'Orignal review was for 3 stars as below:',
#   'Pros:',
#   '+ Premium packaging',
#   '+ Quick pairing with OP phone',
#   '+ Stylish',
#   '+ (Hopefully) good battery',
#   '+ USB C interface - no need for me to carry another charging cable',
#   '+ Enviromental noise cancellation',
#   '+ Quality of mic',
#   '',
#   'Cons:',
#   '',
# ...

# %%
nrev = []

for i in url:
    driver.get(i)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    try:
        rev = driver.find_element_by_xpath("//span[@class='a-size-base review-text']")
        time.sleep(2)
        nrev.append(rev.text)
    
    except:
        nrev.append('-')

# %%
len(nrev)
# Out:
# 33

# %%
nrev
# Out:
# [[' Nice product and good quality'],
#  ['best product ever, i gift to someone. his is very happy. easy to install and use. quality was good. also price was good. and hold the phone very tightly, no need to worry its fall down. best for gps or tracking map.'],
#  [' I liked a lot. Would like to share my friends'],
#  ['Update after 1 month of use.',
#   'There is crackling sound in the background that comes during calls games music anything randomly. During calls, once the crackling starts, it continues. It is known issue with the buds, and you need to reset the device to get it back, and then again the crackling starts in 3-10 hours.',
#   '',
#   'Orignal review was for 3 stars as below:',
#   'Pros:',
#   '+ Premium packaging',
#   '+ Quick pairing with OP phone',
#   '+ Stylish',
#   '+ (Hopefully) good battery',
#   '+ USB C interface - no need for me to carry another charging cable',
#   '+ Enviromental noise cancellation',
#   '+ Quality of mic',
#   '',
#   'Cons:',
#   '',
# ...

# %%
f1 = pd.read_csv("Data")
f2 = pd.read_csv("Data1")
f3 = pd.read_csv("Data2")
f4 = pd.read_csv("Data3")
f5 = pd.read_csv("Data4")

# %%
f1
# Out:
#     Rating                                             Review  \
# 0     4.4★  Good handy phone with decent performance. Good...
# 1     4.4★  Good handy phone with decent performance. Good...
# 2     4.4★  Very nice phone from realme . Loved it Camera ...
# 3     4.4★  Very nice phone from realme . Loved it Camera ...
# 4     4.4★  Really nice phone, delivery is so fast that's ...
# ..     ...                                                ...
# 715   3.9★                                 very nice product.
# 716   4.5★  1.Best in class day today performance.\n2. Bes...
# 717   3.8★  An average android phone with a average displa...
# 718   3.6★                         ITS GOOD. SUPER. EXCELLENT
# 719   4.4★  The first thing i liked on this phone is the d...
#
#            Number of Ratings Number of Reviews
# 0     ['2,29,616 Ratings &']    10,886 Reviews
# 1     ['2,29,616 Ratings &']    10,886 Reviews
# 2       ['66,119 Ratings &']     3,655 Reviews
# ...

# %%
f2
# Out:
#      Rating                                             Review  \
# 0      4.2★  great product 👍 , smooth performance, great ca...
# 1        4★  Nice product from flipkart... I trust this app...
# 2      4.3★  This is the best smart phone in cheap price th...
# 3      3.1★  Oppo N1 Mini(5inch),the smaller sibling to the...
# 4      4.2★  Great mobile very handy and cool look.\n\nPosi...
# ...     ...                                                ...
# 1995   3.5★                                      Velu of monny
# 1996   3.7★                    Build quality is not much good.
# 1997   2.8★                                                  -
# 1998   1.7★                                                  -
# 1999   2.6★                 It is very bad one side low volume
#
#          Number of Ratings Number of Reviews
# 0     ['34,669 Ratings &']     2,917 Reviews
# 1      ['1,648 Ratings &']       263 Reviews
# 2      ['9,582 Ratings &']       640 Reviews
# ...

# %%
f3
# Out:
#      Rating                                             Review  \
# 0      4.2★  great product 👍 , smooth performance, great ca...
# 1        4★  Nice product from flipkart... I trust this app...
# 2      4.3★  This is the best smart phone in cheap price th...
# 3      3.1★  Oppo N1 Mini(5inch),the smaller sibling to the...
# 4      4.2★  Great mobile very handy and cool look.\n\nPosi...
# ...     ...                                                ...
# 2995      -                                                  -
# 2996   4.2★                                              Super
# 2997   4.2★                      Very nice product TX Flipkart
# 2998      -                                                  -
# 2999   3.9★                                               Good
#
#          Number of Ratings Number of Reviews
# 0     ['34,669 Ratings &']     2,917 Reviews
# 1      ['1,648 Ratings &']       263 Reviews
# 2      ['9,582 Ratings &']       640 Reviews
# ...

# %%
f4
# Out:
#      Rating                                             Review  \
# 0        5★                                        Outstanding
# 1      4.2★  After many months of use if can surely say tha...
# 2      4.1★                              Useful Product❤️❤️❤️💟
# 3        4★  Awesome slip i loved it I got my order properl...
# 4      4.5★                               Very good product ❣️
# ...     ...                                                ...
# 3076   4.2★  Freit speakar not work\nHeadphones not work\nC...
# 3077      -  Using for two days now. Its very good tab for ...
# 3078   2.9★                                                  -
# 3079   3.5★  The tab works very fine. 3 gb ram is enough .\...
# 3080   4.3★                                 google not support
#
#          Number of Ratings Number of Reviews
# 0          ['3 Ratings &']         2 Reviews
# 1         ['21 Ratings &']         1 Reviews
# 2      ['2,503 Ratings &']       200 Reviews
# ...

# %%
f5
# Out:
#     Rating                                             Review  \
# 0     4.5★  Excellent product for wireless routers/modems ...
# 1     4.4★  This is exactly what i was looking for. I didn...
# 2     4.4★  This review is based on 10 days use. The adapt...
# 3       4★              Need input to activate, no supporting
# 4     4.3★  I recently bought it to connect my TV with cab...
# ..     ...                                                ...
# 995   4.5★  I have purchased it a week back. Its us really...
# 996   4.2★  Wire quality is pretty good and the length of ...
# 997      -                                                  -
# 998      -                                                  -
# 999     4★  It's just been 2 days since I've started using...
#
#         Number of Ratings Number of Reviews
# 0     ['9,393 Ratings &']     1,462 Reviews
# 1       ['815 Ratings &']       104 Reviews
# 2    ['37,559 Ratings &']     5,174 Reviews
# ...

# %%
frames = [f1,f2,f3,f4,f5]
dataset = pd.concat(frames)
dataset
# Out:
#     Rating                                             Review  \
# 0     4.4★  Good handy phone with decent performance. Good...
# 1     4.4★  Good handy phone with decent performance. Good...
# 2     4.4★  Very nice phone from realme . Loved it Camera ...
# 3     4.4★  Very nice phone from realme . Loved it Camera ...
# 4     4.4★  Really nice phone, delivery is so fast that's ...
# ..     ...                                                ...
# 995   4.5★  I have purchased it a week back. Its us really...
# 996   4.2★  Wire quality is pretty good and the length of ...
# 997      -                                                  -
# 998      -                                                  -
# 999     4★  It's just been 2 days since I've started using...
#
#           Number of Ratings Number of Reviews
# 0    ['2,29,616 Ratings &']    10,886 Reviews
# 1    ['2,29,616 Ratings &']    10,886 Reviews
# 2      ['66,119 Ratings &']     3,655 Reviews
# ...

# %%
dataset.to_csv("Ratings",index = False)
